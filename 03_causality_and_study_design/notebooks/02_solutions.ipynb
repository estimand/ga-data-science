# %% [markdown]
# # Introduction to `pandas`

# %%
import numpy as np
import pandas as pd

# %%
AHP_URL = 'https://files.datapress.com/london/dataset/average-house-prices-borough/2017-09-01T16:00:50.63/land-registry-house-prices-borough.xls'
INCOMES_URL = 'https://files.datapress.com/london/dataset/average-income-tax-payers-borough/2017-05-31T14:05:04.25/income-of-tax-payers.xls'

# %% [markdown]
# ## Exercise 1
#
# Read in the 'Median' sheet from the *Average House Prices by Borough* dataset at `AHP_URL` into a DataFrame called `ahp`.

# %%
ahp = pd.read_excel(AHP_URL, sheet_name='Median')

# %% [markdown]
# ## Exercise 2
#
# Print the `head` and `tail` of `ahp`.

# %%
ahp.head()
# Out:
#         Code                  Area      1995      1996      1997      1998  \
# 0        NaN                   NaN       NaN       NaN       NaN       NaN
# 1  E09000001        City of London  105000.0  138000.0  132000.0  185000.0
# 2  E09000002  Barking and Dagenham   49000.0   49995.0   53500.0   59995.0
# 3  E09000003                Barnet   85500.0   87000.0  100000.0  114000.0
# 4  E09000004                Bexley   62000.0   65000.0   71000.0   79000.0
#
#        1999      2000      2001      2002    ...         2007      2008  \
# 0       NaN       NaN       NaN       NaN    ...          NaN       NaN
# 1  187000.0  203000.0  240000.0  265000.0    ...     417500.0  365000.0
# 2   65000.0   78000.0   89500.0  115250.0    ...     185000.0  190000.0
# 3  135000.0  159000.0  174975.0  207000.0    ...     295000.0  280000.0
# 4   86000.0   98500.0  116972.5  139500.0    ...     212000.0  210000.0
#
#        2009      2010      2011      2012      2013      2014      2015  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  365000.0  410000.0  455000.0  445000.0  625000.0  730000.0  768900.0
# 2  160000.0  170000.0  170000.0  174000.0  180000.0  215000.0  244000.0
# 3  290000.0  325000.0  325000.0  330000.0  345000.0  392500.0  444000.0
# 4  196000.0  215000.0  215000.0  210000.0  225000.0  250000.0  275000.0
#
#        2016
# 0       NaN
# 1  631750.0
# 2  287500.0
# 3  460000.0
# 4  320000.0
#
# [5 rows x 24 columns]

# %%
ahp.tail()
# Out:
#          Code               Area     1995     1996     1997     1998     1999  \
# 46  E12000009         South West  55000.0  57250.0  60000.0  66500.0  74000.0
# 47        NaN                NaN      NaN      NaN      NaN      NaN      NaN
# 48  E92000001            England  55000.0  57500.0  60000.0  66000.0  74000.0
# 49  W92000004              Wales  44000.0  45000.0  47950.0  49500.0  53000.0
# 50  K04000001  England And Wales  54950.0  57000.0  60000.0  65000.0  72950.0
#
#        2000     2001      2002    ...         2007      2008      2009  \
# 46  85000.0  96250.0  123000.0    ...     190000.0  185000.0  175000.0
# 47      NaN      NaN       NaN    ...          NaN       NaN       NaN
# 48  82000.0  92000.0  114000.0    ...     178000.0  173500.0  170000.0
# 49  56500.0  60000.0   71000.0    ...     140000.0  135000.0  132000.0
# 50  80000.0  90000.0  214950.0    ...     175000.0  170000.0  168500.0
#
#         2010      2011      2012      2013      2014      2015      2016
# 46  190000.0  185000.0  187500.0  190000.0  200000.0  215000.0  227000.0
# 47       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 48  185000.0  180000.0  183000.0  187000.0  195000.0  210000.0  220000.0
# 49  134950.0  130000.0  133000.0  133500.0  136000.0  141000.0  145000.0
# 50  182000.0  176000.0  180000.0  184995.0  190000.0  205000.0  215000.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Exercise 3
#
# Filter the DataFrame so that only boroughs are included.
#
# **Hint**: check the structure of `ahp.Code`.

# %%
ahp = ahp[ahp.Code.str.startswith('E09', na=False)]

# %% [markdown]
# ## Exercise 4
#
# Set `Code` as row names (index), dropping it from the DataFrame.

# %%
ahp.set_index('Code', drop=True, inplace=True)

# %% [markdown]
# ## Exercise 5
#
# Examine data types and shape.

# %%
ahp.dtypes
# Out:
# Area     object
# 1995    float64
# 1996    float64
# 1997    float64
# 1998    float64
# 1999    float64
# 2000    float64
# 2001    float64
# 2002    float64
# 2003    float64
# 2004    float64
# 2005    float64
# 2006    float64
# 2007    float64
# 2008    float64
# 2009    float64
# 2010    float64
# 2011    float64
# 2012    float64
# 2013    float64
# 2014    float64
# 2015    float64
# 2016    float64
# dtype: object

# %%
ahp.shape
# Out:
# (33, 23)

# %% [markdown]
# ## Exercise 6
#
# Calculate mean house prices by year.

# %%
ahp.mean()
# Out:
# 1995     78588.409091
# 1996     84625.606061
# 1997     94710.878788
# 1998    108960.303030
# 1999    127674.696970
# 2000    151809.545455
# 2001    170867.045455
# 2002    196926.363636
# 2003    215975.227273
# 2004    232032.742424
# 2005    243993.030303
# 2006    260976.863636
# 2007    294757.424242
# 2008    295305.227273
# 2009    285096.181818
# 2010    314285.575758
# 2011    321724.090909
# 2012    333931.818182
# 2013    368291.651515
# 2014    425016.303030
# 2015    462640.151515
# 2016    493474.545455
# dtype: float64

# %% [markdown]
# ## *Interlude*: melting
#
# We will now convert (`melt`) the dataset from 'wide' to 'long' format.

# %%
ahp = pd.melt(ahp, id_vars='Area', var_name='Year', value_name='Price')
ahp.head()
# Out:
#                    Area  Year     Price
# 0        City of London  1995  105000.0
# 1  Barking and Dagenham  1995   49000.0
# 2                Barnet  1995   85500.0
# 3                Bexley  1995   62000.0
# 4                 Brent  1995   68000.0

# %% [markdown]
# ## Exercise 7
#
# How would you convert the dataset back to 'long' format?

# %%
ahp.pivot_table(values='Price', index='Area', columns='Year', aggfunc='sum')
# Out:
# Year                        1995      1996      1997      1998      1999  \
# Area
# Barking and Dagenham     49000.0   49995.0   53500.0   59995.0   65000.0
# Barnet                   85500.0   87000.0  100000.0  114000.0  135000.0
# Bexley                   62000.0   65000.0   71000.0   79000.0   86000.0
# Brent                    68000.0   73000.0   83500.0   96000.0  112000.0
# Bromley                  76850.0   80000.0   86000.0   99995.0  116500.0
# Camden                  114000.0  127500.0  145000.0  160000.0  190000.0
# City of London          105000.0  138000.0  132000.0  185000.0  187000.0
# Croydon                  60000.0   64500.0   71025.0   79000.0   89000.0
# Ealing                   75000.0   80000.0   90000.0  103000.0  125000.0
# Enfield                  66000.0   70000.0   78000.0   85000.0   94000.0
# Greenwich                61500.0   64000.0   66000.0   75000.0   90000.0
# Hackney                  61975.0   66000.0   77000.0   87500.0  113000.0
# Hammersmith and Fulham  109950.0  122000.0  136000.0  159950.0  191750.0
# Haringey                 66500.0   71950.0   81000.0   91000.0  110000.0
# Harrow                   79975.0   82500.0   94159.0  107500.0  124000.0
# Havering                 66375.0   68500.0   74000.0   82500.0   90000.0
# Hillingdon               71000.0   72500.0   79925.0   89000.0  104950.0
# Hounslow                 73000.0   73000.0   80000.0   95000.0  113000.0
# Islington                95000.0  102250.0  119000.0  145000.0  170000.0
# Kensington and Chelsea  173000.0  195000.0  225000.0  245000.0  285000.0
# Kingston upon Thames     81000.0   86000.0   94950.0  109500.0  129950.0
# Lambeth                  66000.0   75000.0   85000.0  100000.0  121000.0
# Lewisham                 55997.5   57500.0   64000.0   71250.0   82000.0
# Merton                   74500.0   80000.0   84950.0   97000.0  120000.0
# Newham                   46750.0   50000.0   56000.0   63500.0   71995.0
# Redbridge                67995.0   71000.0   76375.0   85000.0   97500.0
# Richmond upon Thames    108000.0  118500.0  136000.0  159000.0  183500.0
# Southwark                71000.0   72950.0   85000.0   99000.0  123000.0
# Sutton                   67000.0   69000.0   75000.0   85000.0   98125.0
# Tower Hamlets            67500.0   77000.0   95000.0  115000.0  140000.0
# Waltham Forest           55000.0   56000.0   62000.0   71000.0   79995.0
# Wandsworth               85500.0   94000.0  108125.0  125000.0  155000.0
# Westminster             127550.0  133000.0  160950.0  177000.0  220000.0
#
# Year                        2000      2001      2002      2003      2004  \
# Area
# Barking and Dagenham     78000.0   89500.0  115250.0  140000.0  159995.0
# Barnet                  159000.0  174975.0  207000.0  233000.0  249000.0
# Bexley                   98500.0  116972.5  139500.0  163000.0  175000.0
# Brent                   139000.0  158000.0  187000.0  210000.0  223500.0
# Bromley                 135000.0  152725.0  176820.0  205000.0  225000.0
# Camden                  235000.0  249995.0  279950.0  273000.0  305000.0
# City of London          203000.0  240000.0  265000.0  310000.0  248863.0
# Croydon                 110000.0  126000.0  150300.0  172000.0  185000.0
# Ealing                  145000.0  163000.0  190000.0  210000.0  231000.0
# Enfield                 114000.0  130000.0  153000.0  180000.0  193000.0
# Greenwich               106500.0  123995.0  150000.0  169995.0  180000.0
# Hackney                 135000.0  160000.0  180000.0  195000.0  215000.0
# Hammersmith and Fulham  222000.0  245000.0  265000.0  280000.0  300250.0
# Haringey                130000.0  150000.0  180000.0  192500.0  213000.0
# Harrow                  147500.0  165000.0  197450.0  230000.0  245000.0
# Havering                110000.0  122500.0  145000.0  173995.0  188000.0
# Hillingdon              124950.0  140000.0  166950.0  190000.0  210000.0
# Hounslow                130000.0  148500.0  174950.0  200000.0  215000.0
# Islington               197500.0  216800.0  245000.0  245500.0  250000.0
# Kensington and Chelsea  343000.0  363000.0  399450.0  405000.0  455000.0
# Kingston upon Thames    154000.0  170000.0  198000.0  215195.0  235000.0
# Lambeth                 156875.0  174200.0  195000.0  202000.0  220000.0
# Lewisham                 99995.0  122000.0  145000.0  165000.0  180000.0
# Merton                  139950.0  160000.0  185000.0  200000.0  224999.0
# Newham                   91995.0  112000.0  141000.0  172997.5  186995.0
# Redbridge               119000.0  138000.0  168000.0  195000.0  217500.0
# Richmond upon Thames    219500.0  227000.0  249950.0  265000.0  291250.0
# Southwark               155000.0  180000.0  190000.0  208500.0  225000.0
# Sutton                  119950.0  132500.0  156000.0  175000.0  187000.0
# Tower Hamlets           162500.0  184950.0  200000.0  211000.0  230000.0
# Waltham Forest           96000.0  118000.0  149000.0  172000.0  187500.0
# Wandsworth              182000.0  204000.0  235000.0  242500.0  260000.0
# Westminster             250000.0  280000.0  319000.0  325000.0  345228.5
#
# Year                      ...          2007      2008      2009      2010  \
# Area                      ...
# Barking and Dagenham      ...      185000.0  190000.0  160000.0  170000.0
# Barnet                    ...      295000.0  280000.0  290000.0  325000.0
# Bexley                    ...      212000.0  210000.0  196000.0  215000.0
# Brent                     ...      280000.0  275000.0  275000.0  283000.0
# Bromley                   ...      260000.0  250000.0  249000.0  275000.0
# Camden                    ...      410000.0  439975.0  417500.0  478700.0
# City of London            ...      417500.0  365000.0  365000.0  410000.0
# Croydon                   ...      222500.0  226500.0  200000.0  220000.0
# Ealing                    ...      270000.0  270000.0  257750.0  279275.0
# Enfield                   ...      233000.0  234600.0  225000.0  241000.0
# Greenwich                 ...      224000.0  230000.0  220000.0  245000.0
# Hackney                   ...      264000.0  265000.0  275000.0  290000.0
# Hammersmith and Fulham    ...      415000.0  435000.0  420000.0  460000.0
# Haringey                  ...      267500.0  250000.0  250000.0  290000.0
# Harrow                    ...      280000.0  275000.0  250000.0  291000.0
# Havering                  ...      222500.0  222500.0  200000.0  221000.0
# Hillingdon                ...      245000.0  245000.0  230000.0  249999.0
# Hounslow                  ...      249995.0  249000.0  240000.0  249950.0
# Islington                 ...      347000.0  350000.0  345000.0  387000.0
# Kensington and Chelsea    ...      640000.0  700000.0  680000.0  750000.0
# Kingston upon Thames      ...      290000.0  285000.0  270000.0  300000.0
# Lambeth                   ...      280000.0  275000.0  275000.0  302000.0
# Lewisham                  ...      225000.0  227000.0  215000.0  235000.0
# Merton                    ...      263000.0  261500.0  250000.0  289000.0
# Newham                    ...      230000.0  235000.0  200000.0  220000.0
# Redbridge                 ...      250000.0  250000.0  230000.0  250000.0
# Richmond upon Thames      ...      381000.0  375000.0  376425.0  400000.0
# Southwark                 ...      276000.0  278000.0  285000.0  314500.0
# Sutton                    ...      233000.0  230000.0  210000.0  235000.0
# Tower Hamlets             ...      290000.0  289997.5  290000.0  305000.0
# Waltham Forest            ...      239000.0  231000.0  211500.0  230000.0
# Wandsworth                ...      355000.0  350000.0  350000.0  380000.0
# Westminster               ...      475000.0  495000.0  499999.0  580000.0
#
# Year                        2011      2012      2013       2014       2015  \
# Area
# Barking and Dagenham    170000.0  174000.0  180000.0   215000.0   244000.0
# Barnet                  325000.0  330000.0  345000.0   392500.0   444000.0
# Bexley                  215000.0  210000.0  225000.0   250000.0   275000.0
# Brent                   300000.0  321000.0  345000.0   380000.0   405000.0
# Bromley                 275000.0  277500.0  295000.0   332747.5   372250.0
# Camden                  485000.0  500000.0  590000.0   670000.0   705000.0
# City of London          455000.0  445000.0  625000.0   730000.0   768900.0
# Croydon                 220000.0  230000.0  237750.0   260000.0   300000.0
# Ealing                  293000.0  310000.0  325000.0   385000.0   428150.0
# Enfield                 240000.0  248000.0  250000.0   280000.0   320000.0
# Greenwich               249995.0  245000.0  275000.0   310000.0   345000.0
# Hackney                 310000.0  325000.0  375000.0   433243.0   483522.0
# Hammersmith and Fulham  465000.0  490000.0  560000.0   655000.0   730000.0
# Haringey                303000.0  315000.0  337000.0   399950.0   430000.0
# Harrow                  294000.0  302000.0  325000.0   365000.0   392925.0
# Havering                220000.0  221000.0  232000.0   250000.0   285000.0
# Hillingdon              249950.0  250000.0  268000.0   302000.0   350000.0
# Hounslow                250000.0  265000.0  280000.0   315000.0   355000.0
# Islington               399950.0  410000.0  465000.0   532500.0   580000.0
# Kensington and Chelsea  790000.0  890000.0  990000.0  1196875.0  1178000.0
# Kingston upon Thames    300000.0  317750.0  335000.0   385000.0   406500.0
# Lambeth                 310000.0  321000.0  350000.0   418250.0   450000.0
# Lewisham                240000.0  249000.0  259350.0   310000.0   353000.0
# Merton                  295000.0  290000.0  320000.0   380500.0   410000.0
# Newham                  219000.0  219000.0  230000.0   250000.0   305000.0
# Redbridge               250000.0  265000.0  272000.0   298000.0   345000.0
# Richmond upon Thames    420000.0  430000.0  475000.0   525000.0   570000.0
# Southwark               320000.0  332500.0  350000.0   415000.0   470000.0
# Sutton                  233000.0  240000.0  250000.0   285000.0   316300.0
# Tower Hamlets           300000.0  305000.0  327500.0   379972.5   419000.0
# Waltham Forest          230000.0  241500.0  263000.0   317000.0   365000.0
# Wandsworth              390000.0  415500.0  462024.5   527000.0   555578.0
# Westminster             600000.0  635000.0  735000.0   880000.0   910000.0
#
# Year                         2016
# Area
# Barking and Dagenham     287500.0
# Barnet                   460000.0
# Bexley                   320000.0
# Brent                    437500.0
# Bromley                  415000.0
# Camden                   720000.0
# City of London           631750.0
# Croydon                  331000.0
# Ealing                   450000.0
# Enfield                  371500.0
# Greenwich                387300.0
# Hackney                  527000.0
# Hammersmith and Fulham   714500.0
# Haringey                 445000.0
# Harrow                   436000.0
# Havering                 330000.0
# Hillingdon               390000.0
# Hounslow                 376200.0
# Islington                600000.0
# Kensington and Chelsea  1200000.0
# Kingston upon Thames     455000.0
# Lambeth                  500000.0
# Lewisham                 379100.0
# Merton                   440000.0
# Newham                   351000.0
# Redbridge                385000.0
# Richmond upon Thames     599950.0
# Southwark                512100.0
# Sutton                   340000.0
# Tower Hamlets            456435.0
# Waltham Forest           413000.0
# Wandsworth               632825.0
# Westminster              990000.0
#
# [33 rows x 22 columns]

# %% [markdown]
# ## Exercise 8
#
# Convert `Year` to integer.

# %%
ahp['Year'] = ahp.Year.astype('int')

# %% [markdown]
# ## Exercise 9
#
# Calculate mean house prices by year.

# %%
ahp.groupby('Year').Price.mean()
# Out:
# Year
# 1995     78588.409091
# 1996     84625.606061
# 1997     94710.878788
# 1998    108960.303030
# 1999    127674.696970
# 2000    151809.545455
# 2001    170867.045455
# 2002    196926.363636
# 2003    215975.227273
# 2004    232032.742424
# 2005    243993.030303
# 2006    260976.863636
# 2007    294757.424242
# 2008    295305.227273
# 2009    285096.181818
# 2010    314285.575758
# 2011    321724.090909
# 2012    333931.818182
# 2013    368291.651515
# 2014    425016.303030
# 2015    462640.151515
# 2016    493474.545455
# Name: Price, dtype: float64

# %% [markdown]
# ## Exercise 10
#
# Calculate mean house prices by borough using only data from 2010 onwards.

# %%
ahp[ahp.Year >= 2010].groupby('Area').Price.mean()
# Out:
# Area
# Barking and Dagenham      205785.714286
# Barnet                    374500.000000
# Bexley                    244285.714286
# Brent                     353071.428571
# Bromley                   320356.785714
# Camden                    592671.428571
# City of London            580807.142857
# Croydon                   256964.285714
# Ealing                    352917.857143
# Enfield                   278642.857143
# Greenwich                 293899.285714
# Hackney                   391966.428571
# Hammersmith and Fulham    582071.428571
# Haringey                  359992.857143
# Harrow                    343703.571429
# Havering                  251285.714286
# Hillingdon                294278.428571
# Hounslow                  298735.714286
# Islington                 482064.285714
# Kensington and Chelsea    999267.857143
# Kingston upon Thames      357035.714286
# Lambeth                   378750.000000
# Lewisham                  289350.000000
# Merton                    346357.142857
# Newham                    256285.714286
# Redbridge                 295000.000000
# Richmond upon Thames      488564.285714
# Southwark                 387728.571429
# Sutton                    271328.571429
# Tower Hamlets             356129.642857
# Waltham Forest            294214.285714
# Wandsworth                480418.214286
# Westminster               761428.571429
# Name: Price, dtype: float64

# %% [markdown]
# ## Exercise 11
#
# Identify the three boroughs with the highest mean house prices.

# %%
ahp.groupby('Area').Price.mean().sort_values(ascending=False).head(3)
# Out:
# Area
# Kensington and Chelsea    595151.136364
# Westminster               451033.068182
# Camden                    371732.727273
# Name: Price, dtype: float64

# %% [markdown]
# ## Exercise 12
#
# Read in the *Average Income of Tax Payers by Borough* from `INCOMES_URL` into a DataFrame called `incomes`, keeping only the columns indicating the borough and the medians for each year.
# Rename the columns to only include the starting year (e.g. '1999-00' = 1999).

# %%
incomes = pd.read_excel(INCOMES_URL, sheet_name='Total Income').reset_index()
incomes = incomes[incomes.iloc[:, 0].str.startswith('E09', na=False)]
column_names = ['Area'] + list(incomes.columns[2::3].str.extract('(\\d+)-', expand=False))
incomes = pd.concat([incomes.iloc[:, 1], incomes.iloc[:, 4::3]], axis=1)
incomes.columns = column_names

# %% [markdown]
# ## Exercise 13
#
# 'Melt' the DataFrame and adjust data types as needed.

# %%
incomes = pd.melt(incomes, id_vars='Area', var_name='Year', value_name='Income')
incomes['Year'] = incomes.Year.astype('int')
incomes['Income'] = incomes.Income.astype('float')

# %% [markdown]
# ## Exercise 14
#
# Merge `incomes` with `ahp`, keeping only observations found in both DataFrames.

# %%
ahp_incomes = pd.merge(ahp, incomes, how='inner')

# %% [markdown]
# ## Exercise 15
#
# Compute mean house prices and incomes by year.

# %%
ahp_incomes.pivot_table(values=['Price', 'Income'], index='Year')
# Out:
#             Income          Price
# Year
# 1999  17361.290323  125800.483871
# 2000  19116.129032  149555.322581
# 2001  19129.032258  169084.274194
# 2002  19500.000000  195181.290323
# 2003  19761.290323  214418.951613
# 2004  19877.419355  230026.790323
# 2005  21435.483871  242316.774194
# 2006  21867.741935  259104.435484
# 2007  23135.483871  292128.870968
# 2009  24958.064516  282637.064516
# 2010  24709.677419  311981.419355
# 2011  25177.419355  319254.677419
# 2012  26238.709677  331354.838710
# 2013  27393.548387  365923.370968
# 2014  27970.967742  423081.870968

# %% [markdown]
# ## Exercise 16
#
# Compute the correlation between house prices and incomes by area.

# %%
ahp_incomes.groupby('Area').Price.corr(ahp_incomes.Income)
# Out:
# Area
# Barking and Dagenham      0.868372
# Barnet                    0.919618
# Bexley                    0.846362
# Brent                     0.920543
# Bromley                   0.951147
# Camden                    0.967402
# City of London            0.595057
# Croydon                   0.905613
# Ealing                    0.969878
# Enfield                   0.902590
# Greenwich                 0.920023
# Hackney                   0.968930
# Hammersmith and Fulham    0.959749
# Haringey                  0.947072
# Harrow                    0.932091
# Havering                  0.927207
# Hillingdon                0.970027
# Hounslow                  0.949986
# Islington                 0.955748
# Kensington and Chelsea    0.923848
# Lambeth                   0.968563
# Lewisham                  0.959669
# Merton                    0.915172
# Newham                    0.779182
# Redbridge                 0.900974
# Southwark                 0.987826
# Sutton                    0.937435
# Tower Hamlets             0.943302
# Waltham Forest            0.901459
# Wandsworth                0.974400
# Westminster               0.933688
# Name: Price, dtype: float64
